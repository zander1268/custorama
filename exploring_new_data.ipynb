# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import lifetimes
from lifetimes.plotting import plot_period_transactions, plot_calibration_purchases_vs_holdout_purchases
from lifetimes import BetaGeoFitter
from datetime import timedelta
from datetime import datetime
from dateutil import parser

# %%
df = pd.read_csv("data/OnlineRetail_2yrs.csv")

# %%
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS      12.0
# 1       489434    79323P                   PINK CHERRY LIGHTS      12.0
# 2       489434    79323W                  WHITE CHERRY LIGHTS      12.0
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE       48.0
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX      24.0
# ...        ...       ...                                  ...       ...
# 981326  581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT      12.0
# 981327  581586     22061  LARGE CAKE STAND  HANGING STRAWBERY       8.0
# 981328  581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK      24.0
# 981329  581586     21217        RED RETROSPOT ROUND CAKE TINS      24.0
# 981330  581586     20685                DOORMAT RED RETROSPOT      10.0
#
#             InvoiceDate  Price  Customer ID         Country
# 0        1/12/2009 7:45   6.95      13085.0  United Kingdom
# 1        1/12/2009 7:45   6.75      13085.0  United Kingdom
# 2        1/12/2009 7:45   6.75      13085.0  United Kingdom
# 3        1/12/2009 7:45   2.10      13085.0  United Kingdom
# 4        1/12/2009 7:45   1.25      13085.0  United Kingdom
# ...                 ...    ...          ...             ...
# 981326  9/12/2011 12:31   1.95      15804.0  United Kingdom
# 981327  9/12/2011 12:49   2.95      13113.0  United Kingdom
# 981328  9/12/2011 12:49   1.25      13113.0  United Kingdom
# 981329  9/12/2011 12:49   8.95      13113.0  United Kingdom
# 981330  9/12/2011 12:49   7.08      13113.0  United Kingdom
#
# [981331 rows x 8 columns]

# %%
len(set(df["Invoice"].values))
# Out:
# 49109
